# %%
# brute_force.py

import math
import time
from itertools import permutations


class BruteForce:
    def __init__(self, file_path, cutoff):
        """
        Initialize the BruteForce object with TSP file and cutoff time.
        Args:
            file_path (str): Path to the .tsp file.
            cutoff (float): Time cutoff (in seconds).
        """
        self.file_path = file_path
        self.cutoff = cutoff
        self.coordinates = self._parse_tsp_file()
        self.num_cities = len(self.coordinates)
        self.distances = self._precompute_distances()
        self.best_tour_length = float('inf')

    def _parse_tsp_file(self):
        """
        Parses a .tsp file and extracts the node coordinates.
        Returns:
            list: List of tuples representing coordinates of the locations [(x1, y1), (x2, y2), ...].
        """
        coordinates = []
        with open(self.file_path, 'r') as file:
            lines = file.readlines()

        # Locate the "NODE_COORD_SECTION" and read coordinates
        coordinates_start = lines.index("NODE_COORD_SECTION\n") + 1
        for line in lines[coordinates_start:]:
            if line.strip() == "EOF":
                break
            _, x, y = line.strip().split()
            coordinates.append((float(x), float(y)))

        return coordinates

    def _euclidean_distance(self, p1, p2):
        """Calculate Euclidean distance between two points."""
        return math.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)

    def _precompute_distances(self):
        """Precomputes the distances between all cities."""
        return [[self._euclidean_distance(self.coordinates[i], self.coordinates[j])
                 for j in range(self.num_cities)] for i in range(self.num_cities)]

    def _calculate_tour_length(self, tour):
        """Calculates the total distance of a given tour."""
        return sum(self.distances[tour[i]][tour[(i + 1) % self.num_cities]] for i in range(self.num_cities))

    def find_best_tour_length(self):
        """
        Solves TSP using a brute force approach.
        Returns:
            float: The best tour length found.
        """
        start_time = time.time()
        all_tours = permutations(range(self.num_cities))  # Generate all permutations of cities

        for tour in all_tours:
            # Check time cutoff
            if time.time() - start_time > self.cutoff:
                break

            # Calculate the tour length
            tour_length = self._calculate_tour_length(tour)

            # Update the best tour length
            if tour_length < self.best_tour_length:
                self.best_tour_length = tour_length

        return self.best_tour_length


# Example Usage
# if __name__ == "__main__":
#     file_path = "data/Atlanta.tsp"  # Replace with your .tsp file path
#     cutoff = 60  # Time cutoff in seconds

#     brute_force = BruteForce(file_path, cutoff)
#     best_tour_length = brute_force.find_best_tour_length()
#     print(f"Best Tour Length: {best_tour_length}")

# %%
import os
import matplotlib.pyplot as plt

# List of cities and corresponding file paths
CITIES = [
    "Atlanta", "Berlin", "Boston", "Champaign", "Cincinnati", "Denver",
    "NYC", "Philadelphia", "Roanoke", "SanFrancisco", "Toronto",
    "UKansasState", "UMissouri"
]
DATA_DIR = "./"  # Directory where the .tsp files are located
CUTOFF_TIMES = [0, 2, 5, 10, 20, 40, 50, 100, 150, 200, 500]
PLOT_DIR = "./plots"  # Directory to save the plots

# Create the output directory for plots if it doesn't exist
os.makedirs(PLOT_DIR, exist_ok=True)

def run_brute_force_and_plot():
    for city in CITIES:
        tsp_file = os.path.join(DATA_DIR, f"{city}.tsp")
        best_tour_lengths = []

        print(f"Running BruteForce for city: {city}")

        # Run the algorithm for each cutoff time
        for cutoff in CUTOFF_TIMES:
            brute_force_solver = BruteForce(file_path=tsp_file, cutoff=cutoff)
            best_tour_length = brute_force_solver.find_best_tour_length()
            best_tour_lengths.append(best_tour_length)
            print(f"  Cutoff: {cutoff}s, Best Tour Length: {best_tour_length}")

        # Plot the results
        plot_city_results(city, CUTOFF_TIMES, best_tour_lengths)

def plot_city_results(city, cutoff_times, best_tour_lengths):
    plt.figure()
    plt.plot(cutoff_times, best_tour_lengths, marker="o", linestyle="-")
    plt.title(f"{city} - Best Tour Length vs Cutoff Time")
    plt.xlabel("Cutoff Time (s)")
    plt.ylabel("Best Tour Length")
    plt.grid(True)
    plt.savefig(os.path.join(PLOT_DIR, f"{city}_brute_force_plot.png"))
    plt.close()
    print(f"Plot saved for {city}.")

if __name__ == "__main__":
    run_brute_force_and_plot()
# Out:
# Running BruteForce for city: Atlanta
#   Cutoff: 0s, Best Tour Length: inf
#   Cutoff: 2s, Best Tour Length: 4109866.624376217
#   Cutoff: 5s, Best Tour Length: 4109866.624376217
#   Cutoff: 10s, Best Tour Length: 3937992.7000216707
#   Cutoff: 20s, Best Tour Length: 3816909.110191864
#   Cutoff: 40s, Best Tour Length: 3720831.531662631
#   Cutoff: 50s, Best Tour Length: 3630532.301182535
#   Cutoff: 100s, Best Tour Length: 3630532.301182535
#   Cutoff: 150s, Best Tour Length: 3630532.301182535
#   Cutoff: 200s, Best Tour Length: 3630532.301182535
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-650e7ad985dd> in <cell line: 45>()
#      44
#      45 if __name__ == "__main__":
# ---> 46     run_brute_force_and_plot()
#
# <ipython-input-4-650e7ad985dd> in run_brute_force_and_plot()
#      25         for cutoff in CUTOFF_TIMES:
#      26             brute_force_solver = BruteForce(file_path=tsp_file, cutoff=cutoff)
# ---> 27             best_tour_length = brute_force_solver.find_best_tour_length()
#      28             best_tour_lengths.append(best_tour_length)
#      29             print(f"  Cutoff: {cutoff}s, Best Tour Length: {best_tour_length}")
#
# <ipython-input-2-153cd38ed4a7> in find_best_tour_length(self)
#      69
#      70             # Calculate the tour length
# ---> 71             tour_length = self._calculate_tour_length(tour)
#      72
#      73             # Update the best tour length
#
# <ipython-input-2-153cd38ed4a7> in _calculate_tour_length(self, tour)
#      52     def _calculate_tour_length(self, tour):
#      53         """Calculates the total distance of a given tour."""
# ---> 54         return sum(self.distances[tour[i]][tour[(i + 1) % self.num_cities]] for i in range(self.num_cities))
#      55
#      56     def find_best_tour_length(self):
#
# <ipython-input-2-153cd38ed4a7> in <genexpr>(.0)
#      52     def _calculate_tour_length(self, tour):
#      53         """Calculates the total distance of a given tour."""
# ---> 54         return sum(self.distances[tour[i]][tour[(i + 1) % self.num_cities]] for i in range(self.num_cities))
#      55
#      56     def find_best_tour_length(self):
#
# KeyboardInterrupt:

# %%
# local_search.py

import math
import random
import time


class LocalSearch:
    def __init__(self, file_path, cutoff, seed):
        """
        Initialize the LocalSearch object with TSP file, cutoff time, and random seed.
        Args:
            file_path (str): Path to the .tsp file.
            cutoff (float): Time cutoff (in seconds).
            seed (int): Random seed for reproducibility.
        """
        self.file_path = file_path
        self.cutoff = cutoff
        self.seed = seed
        self.coordinates = self._parse_tsp_file()
        self.num_cities = len(self.coordinates)
        self.distances = self._precompute_distances()

    def _parse_tsp_file(self):
        """
        Parses a .tsp file and extracts the node coordinates.
        Returns:
            list: List of tuples representing coordinates of the locations [(x1, y1), (x2, y2), ...].
        """
        coordinates = []
        with open(self.file_path, 'r') as file:
            lines = file.readlines()

        # Locate the "NODE_COORD_SECTION" and read coordinates
        coordinates_start = lines.index("NODE_COORD_SECTION\n") + 1
        for line in lines[coordinates_start:]:
            if line.strip() == "EOF":
                break
            _, x, y = line.strip().split()
            coordinates.append((float(x), float(y)))

        return coordinates

    def _euclidean_distance(self, p1, p2):
        """Calculate Euclidean distance between two points."""
        return math.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)

    def _precompute_distances(self):
        """Precomputes the distances between all cities."""
        return [[self._euclidean_distance(self.coordinates[i], self.coordinates[j])
                 for j in range(self.num_cities)] for i in range(self.num_cities)]

    def _calculate_total_distance(self, route):
        """Calculates the total distance of a route."""
        total_distance = sum(self.distances[route[i]][route[i + 1]] for i in range(len(route) - 1))
        total_distance += self.distances[route[-1]][route[0]]  # Return to start
        return total_distance

    def _get_neighbor(self, route):
        """
        Generates a neighboring solution by swapping two cities.
        Args:
            route (list): Current route.
        Returns:
            list: A new route with two cities swapped.
        """
        new_route = route[:]
        i, j = random.sample(range(len(route)), 2)
        new_route[i], new_route[j] = new_route[j], new_route[i]
        return new_route

    def _acceptance_probability(self, old_cost, new_cost, temperature):
        """
        Calculates the probability of accepting a worse solution.
        Args:
            old_cost (float): Current solution cost.
            new_cost (float): New solution cost.
            temperature (float): Current temperature.
        Returns:
            float: Acceptance probability.
        """
        if new_cost < old_cost:
            return 1.0
        return math.exp((old_cost - new_cost) / temperature)

    def find_best_distance(self):
        """
        Solves TSP using Simulated Annealing.
        Returns:
            float: The best distance found.
        """
        random.seed(self.seed)
        cities = list(range(self.num_cities))

        # Initialize variables
        current_route = cities[:]
        random.shuffle(current_route)
        current_distance = self._calculate_total_distance(current_route)

        best_distance = current_distance

        start_time = time.time()
        temperature = 100000.0  # Initial temperature
        cooling_rate = 0.9999  # Cooling rate
        min_temperature = 1e-4  # Stopping temperature
        while time.time() - start_time < self.cutoff and temperature > min_temperature:
            # Generate a neighboring solution
            neighbor_route = self._get_neighbor(current_route)
            neighbor_distance = self._calculate_total_distance(neighbor_route)

            # Decide whether to accept the new solution
            if self._acceptance_probability(current_distance, neighbor_distance, temperature) > random.random():
                current_route = neighbor_route
                current_distance = neighbor_distance

                # Update the best solution
                if current_distance < best_distance:
                    best_distance = current_distance

            # Cool down the temperature
            temperature *= cooling_rate

        return best_distance


# # Example Usage
# if __name__ == "__main__":
#     file_path = "data/Atlanta.tsp"  # Replace with your .tsp file path
#     cutoff = 60  # Time cutoff in seconds
#     seed = 42  # Random seed for reproducibility

#     local_search = LocalSearch(file_path, cutoff, seed)
#     best_distance = local_search.find_best_distance()
#     print(f"Best Distance: {best_distance}")

# %%
import os
import matplotlib.pyplot as plt

# List of cities and corresponding file paths
CITIES = [
    "Atlanta", "Berlin", "Boston", "Champaign", "Cincinnati", "Denver",
    "NYC", "Philadelphia", "Roanoke", "SanFrancisco", "Toronto",
    "UKansasState", "UMissouri"
]
DATA_DIR = "./"  # Directory where the .tsp files are located
CUTOFF_TIMES = [
    0, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6,
    0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 1
]
PLOT_DIR = "./plots"  # Directory to save the plots

# Create the output directory for plots if it doesn't exist
os.makedirs(PLOT_DIR, exist_ok=True)

def run_local_search_and_plot():
    for city in CITIES:
        tsp_file = os.path.join(DATA_DIR, f"{city}.tsp")
        best_distances = []

        print(f"Running LocalSearch for city: {city}")

        # Run the algorithm for each cutoff time
        for cutoff in CUTOFF_TIMES:
            local_search_solver = LocalSearch(file_path=tsp_file, cutoff=cutoff, seed=42)
            best_distance = local_search_solver.find_best_distance()
            best_distances.append(best_distance)
            print(f"  Cutoff: {cutoff}s, Best Distance: {best_distance}")

        # Plot the results
        plot_city_results(city, CUTOFF_TIMES, best_distances)

def plot_city_results(city, cutoff_times, best_distances):
    plt.figure()
    plt.plot(cutoff_times, best_distances, marker="o", linestyle="-")
    plt.title(f"{city} - Best Distance vs Cutoff Time")
    plt.xlabel("Cutoff Time (s)")
    plt.ylabel("Best Distance")
    plt.grid(True)
    plt.savefig(os.path.join(PLOT_DIR, f"{city}_local_search_plot.png"))
    plt.close()
    print(f"Plot saved for {city}.")

if __name__ == "__main__":
    run_local_search_and_plot()
# Out:
# Running LocalSearch for city: Atlanta
#   Cutoff: 0s, Best Distance: 4504201.150699763
#   Cutoff: 0.1s, Best Distance: 2060176.4044786252
#   Cutoff: 0.15s, Best Distance: 2023778.354086583
#   Cutoff: 0.2s, Best Distance: 2023778.354086583
#   Cutoff: 0.25s, Best Distance: 2023778.354086583
#   Cutoff: 0.3s, Best Distance: 2023778.354086583
#   Cutoff: 0.35s, Best Distance: 2023778.354086583
#   Cutoff: 0.4s, Best Distance: 2023778.354086583
#   Cutoff: 0.45s, Best Distance: 2023778.354086583
#   Cutoff: 0.5s, Best Distance: 2023778.354086583
#   Cutoff: 0.55s, Best Distance: 2023778.354086583
#   Cutoff: 0.6s, Best Distance: 2023778.354086583
#   Cutoff: 0.65s, Best Distance: 2023778.354086583
#   Cutoff: 0.7s, Best Distance: 2023778.354086583
#   Cutoff: 0.75s, Best Distance: 2023778.354086583
#   Cutoff: 0.8s, Best Distance: 2023778.354086583
#   Cutoff: 0.85s, Best Distance: 2023778.354086583
#   Cutoff: 0.9s, Best Distance: 2023778.354086583
#   Cutoff: 1s, Best Distance: 2023778.354086583
# Plot saved for Atlanta.
# Running LocalSearch for city: Berlin
#   Cutoff: 0s, Best Distance: 26308.67749046573
#   Cutoff: 0.1s, Best Distance: 23003.14649052188
#   Cutoff: 0.15s, Best Distance: 22819.1420908717
#   Cutoff: 0.2s, Best Distance: 22819.1420908717
#   Cutoff: 0.25s, Best Distance: 22819.1420908717
#   Cutoff: 0.3s, Best Distance: 22819.1420908717
#   Cutoff: 0.35s, Best Distance: 22819.1420908717
#   Cutoff: 0.4s, Best Distance: 22819.1420908717
#   Cutoff: 0.45s, Best Distance: 22819.1420908717
#   Cutoff: 0.5s, Best Distance: 22819.1420908717
#   Cutoff: 0.55s, Best Distance: 22819.1420908717
#   Cutoff: 0.6s, Best Distance: 21915.428532769107
#   Cutoff: 0.65s, Best Distance: 20428.93084806433
#   Cutoff: 0.7s, Best Distance: 19514.528210018372
#   Cutoff: 0.75s, Best Distance: 16732.318617360295
#   Cutoff: 0.8s, Best Distance: 19846.719600620978
#   Cutoff: 0.85s, Best Distance: 22819.1420908717
#   Cutoff: 0.9s, Best Distance: 22819.1420908717
#   Cutoff: 1s, Best Distance: 21605.601922580412
# Plot saved for Berlin.
# Running LocalSearch for city: Boston
#   Cutoff: 0s, Best Distance: 2622098.9712166684
#   Cutoff: 0.1s, Best Distance: 1517927.4922451475
#   Cutoff: 0.15s, Best Distance: 1491320.1439689216
#   Cutoff: 0.2s, Best Distance: 1322317.5000409156
#   Cutoff: 0.25s, Best Distance: 1118286.404533814
#   Cutoff: 0.3s, Best Distance: 1035556.0952511984
#   Cutoff: 0.35s, Best Distance: 1032307.1796778315
#   Cutoff: 0.4s, Best Distance: 979993.1021867984
#   Cutoff: 0.45s, Best Distance: 970224.5489537388
#   Cutoff: 0.5s, Best Distance: 970224.5489537388
#   Cutoff: 0.55s, Best Distance: 970012.3614464577
#   Cutoff: 0.6s, Best Distance: 970012.3614464577
#   Cutoff: 0.65s, Best Distance: 970012.3614464577
#   Cutoff: 0.7s, Best Distance: 970012.3614464577
#   Cutoff: 0.75s, Best Distance: 970012.3614464577
#   Cutoff: 0.8s, Best Distance: 970012.3614464577
#   Cutoff: 0.85s, Best Distance: 970012.3614464577
#   Cutoff: 0.9s, Best Distance: 970012.3614464577
#   Cutoff: 1s, Best Distance: 970012.3614464577
# Plot saved for Boston.
# Running LocalSearch for city: Champaign
#   Cutoff: 0s, Best Distance: 211295.05036233622
#   Cutoff: 0.1s, Best Distance: 169234.63137031504
#   Cutoff: 0.15s, Best Distance: 169234.63137031504
#   Cutoff: 0.2s, Best Distance: 169234.63137031504
#   Cutoff: 0.25s, Best Distance: 169234.63137031504
#   Cutoff: 0.3s, Best Distance: 169234.63137031504
#   Cutoff: 0.35s, Best Distance: 169234.63137031504
#   Cutoff: 0.4s, Best Distance: 169234.63137031504
#   Cutoff: 0.45s, Best Distance: 169234.63137031504
#   Cutoff: 0.5s, Best Distance: 161923.08272131227
#   Cutoff: 0.55s, Best Distance: 108972.2943122683
#   Cutoff: 0.6s, Best Distance: 94083.59824664866
#   Cutoff: 0.65s, Best Distance: 92908.08511570828
#   Cutoff: 0.7s, Best Distance: 84345.3012100439
#   Cutoff: 0.75s, Best Distance: 73031.032232978
#   Cutoff: 0.8s, Best Distance: 62203.568274437406
#   Cutoff: 0.85s, Best Distance: 58287.94546975145
#   Cutoff: 0.9s, Best Distance: 56678.21099124609
#   Cutoff: 1s, Best Distance: 68677.00299703251
# Plot saved for Champaign.
# Running LocalSearch for city: Cincinnati
#   Cutoff: 0s, Best Distance: 366762.71199112403
#   Cutoff: 0.1s, Best Distance: 280743.18871177774
#   Cutoff: 0.15s, Best Distance: 277952.5864957148
#   Cutoff: 0.2s, Best Distance: 277952.58649571467
#   Cutoff: 0.25s, Best Distance: 277952.58649571467
#   Cutoff: 0.3s, Best Distance: 277952.58649571467
#   Cutoff: 0.35s, Best Distance: 277952.58649571467
#   Cutoff: 0.4s, Best Distance: 277952.58649571467
#   Cutoff: 0.45s, Best Distance: 277952.58649571467
#   Cutoff: 0.5s, Best Distance: 277952.58649571467
#   Cutoff: 0.55s, Best Distance: 277952.58649571467
#   Cutoff: 0.6s, Best Distance: 277952.58649571467
#   Cutoff: 0.65s, Best Distance: 277952.58649571467
#   Cutoff: 0.7s, Best Distance: 277952.58649571467
#   Cutoff: 0.75s, Best Distance: 277952.58649571467
#   Cutoff: 0.8s, Best Distance: 277952.58649571467
#   Cutoff: 0.85s, Best Distance: 277952.58649571467
#   Cutoff: 0.9s, Best Distance: 277952.58649571467
#   Cutoff: 1s, Best Distance: 277952.58649571467
# Plot saved for Cincinnati.
# Running LocalSearch for city: Denver
#   Cutoff: 0s, Best Distance: 525467.2875769043
#   Cutoff: 0.1s, Best Distance: 437036.66076021444
#   Cutoff: 0.15s, Best Distance: 437036.66076021444
#   Cutoff: 0.2s, Best Distance: 437036.66076021444
#   Cutoff: 0.25s, Best Distance: 437036.66076021444
#   Cutoff: 0.3s, Best Distance: 437036.66076021444
#   Cutoff: 0.35s, Best Distance: 435448.1359593307
#   Cutoff: 0.4s, Best Distance: 397430.22147914395
#   Cutoff: 0.45s, Best Distance: 396714.0393797105
#   Cutoff: 0.5s, Best Distance: 375820.88393236307
#   Cutoff: 0.55s, Best Distance: 367594.29825567995
#   Cutoff: 0.6s, Best Distance: 308496.9342996124
#   Cutoff: 0.65s, Best Distance: 307047.7810285017
#   Cutoff: 0.7s, Best Distance: 248626.95840221492
#   Cutoff: 0.75s, Best Distance: 218621.74173599534
#   Cutoff: 0.8s, Best Distance: 367594.29825567995
#   Cutoff: 0.85s, Best Distance: 396714.0393797105
#   Cutoff: 0.9s, Best Distance: 375820.88393236307
#   Cutoff: 1s, Best Distance: 218621.74173599534
# Plot saved for Denver.
# Running LocalSearch for city: NYC
#   Cutoff: 0s, Best Distance: 7114187.250722174
#   Cutoff: 0.1s, Best Distance: 3714955.5842359182
#   Cutoff: 0.15s, Best Distance: 3377798.6190989604
#   Cutoff: 0.2s, Best Distance: 2979690.358831398
#   Cutoff: 0.25s, Best Distance: 2884132.130397528
#   Cutoff: 0.3s, Best Distance: 2640212.0006051986
#   Cutoff: 0.35s, Best Distance: 2356090.3915037205
#   Cutoff: 0.4s, Best Distance: 2244940.175953208
#   Cutoff: 0.45s, Best Distance: 2093858.0879809635
#   Cutoff: 0.5s, Best Distance: 2038937.711896124
#   Cutoff: 0.55s, Best Distance: 1945125.597105643
#   Cutoff: 0.6s, Best Distance: 1842069.8108515653
#   Cutoff: 0.65s, Best Distance: 1832125.1396525907
#   Cutoff: 0.7s, Best Distance: 1832125.1396525907
#   Cutoff: 0.75s, Best Distance: 1832125.1396525907
#   Cutoff: 0.8s, Best Distance: 1820378.0653304667
#   Cutoff: 0.85s, Best Distance: 1820378.0653304667
#   Cutoff: 0.9s, Best Distance: 1820378.0653304667
#   Cutoff: 1s, Best Distance: 1820378.0653304667
# Plot saved for NYC.
# Running LocalSearch for city: Philadelphia
#   Cutoff: 0s, Best Distance: 4241068.430486764
#   Cutoff: 0.1s, Best Distance: 1765454.7108229932
#   Cutoff: 0.15s, Best Distance: 1765454.7108229932
#   Cutoff: 0.2s, Best Distance: 1613810.8788991834
#   Cutoff: 0.25s, Best Distance: 1559661.0347611192
#   Cutoff: 0.3s, Best Distance: 1500601.6974079537
#   Cutoff: 0.35s, Best Distance: 1500601.6974079537
#   Cutoff: 0.4s, Best Distance: 1448810.8637828617
#   Cutoff: 0.45s, Best Distance: 1430512.0746071409
#   Cutoff: 0.5s, Best Distance: 1403469.2885747917
#   Cutoff: 0.55s, Best Distance: 1403469.2885747917
#   Cutoff: 0.6s, Best Distance: 1403469.2885747917
#   Cutoff: 0.65s, Best Distance: 1403469.2885747917
#   Cutoff: 0.7s, Best Distance: 1403469.2885747917
#   Cutoff: 0.75s, Best Distance: 1403469.2885747917
#   Cutoff: 0.8s, Best Distance: 1403469.2885747917
#   Cutoff: 0.85s, Best Distance: 1403469.2885747917
#   Cutoff: 0.9s, Best Distance: 1403469.2885747917
#   Cutoff: 1s, Best Distance: 1403469.2885747917
# Plot saved for Philadelphia.
# Running LocalSearch for city: Roanoke
#   Cutoff: 0s, Best Distance: 7046981.190322248
#   Cutoff: 0.1s, Best Distance: 6027584.466803698
#   Cutoff: 0.15s, Best Distance: 6027584.466803698
#   Cutoff: 0.2s, Best Distance: 6027584.466803698
#   Cutoff: 0.25s, Best Distance: 5688654.934860418
#   Cutoff: 0.3s, Best Distance: 5473514.986873501
#   Cutoff: 0.35s, Best Distance: 5319013.856261669
#   Cutoff: 0.4s, Best Distance: 5319013.856261669
#   Cutoff: 0.45s, Best Distance: 5319013.856261669
#   Cutoff: 0.5s, Best Distance: 5319013.856261669
#   Cutoff: 0.55s, Best Distance: 5473514.986873501
#   Cutoff: 0.6s, Best Distance: 5319013.856261669
#   Cutoff: 0.65s, Best Distance: 5319013.856261669
#   Cutoff: 0.7s, Best Distance: 5319013.856261669
#   Cutoff: 0.75s, Best Distance: 3722379.3679452036
#   Cutoff: 0.8s, Best Distance: 3639787.379190257
#   Cutoff: 0.85s, Best Distance: 3557037.146224446
#   Cutoff: 0.9s, Best Distance: 3366835.981814879
#   Cutoff: 1s, Best Distance: 3216359.0045070276
# Plot saved for Roanoke.
# Running LocalSearch for city: SanFrancisco
#   Cutoff: 0s, Best Distance: 6298391.208860699
#   Cutoff: 0.1s, Best Distance: 4082373.1267812317
#   Cutoff: 0.15s, Best Distance: 3862041.7048837417
#   Cutoff: 0.2s, Best Distance: 3829448.3228996657
#   Cutoff: 0.25s, Best Distance: 3698730.5020950157
#   Cutoff: 0.3s, Best Distance: 2762716.8994519915
#   Cutoff: 0.35s, Best Distance: 2658463.70599744
#   Cutoff: 0.4s, Best Distance: 2272800.40590921
#   Cutoff: 0.45s, Best Distance: 1977815.4838071512
#   Cutoff: 0.5s, Best Distance: 1967939.4211712214
#   Cutoff: 0.55s, Best Distance: 1705452.1571939278
#   Cutoff: 0.6s, Best Distance: 1618201.4528177292
#   Cutoff: 0.65s, Best Distance: 1397876.499096041
#   Cutoff: 0.7s, Best Distance: 1401921.4754484107
#   Cutoff: 0.75s, Best Distance: 2007125.8087019688
#   Cutoff: 0.8s, Best Distance: 2007125.8087019688
#   Cutoff: 0.85s, Best Distance: 1977815.4838071512
#   Cutoff: 0.9s, Best Distance: 1263595.824587326
#   Cutoff: 1s, Best Distance: 1238283.564602815
# Plot saved for SanFrancisco.
# Running LocalSearch for city: Toronto
#   Cutoff: 0s, Best Distance: 9654186.969229814
#   Cutoff: 0.1s, Best Distance: 5805196.060066536
#   Cutoff: 0.15s, Best Distance: 5805196.060066536
#   Cutoff: 0.2s, Best Distance: 5023388.511550878
#   Cutoff: 0.25s, Best Distance: 4952361.345738851
#   Cutoff: 0.3s, Best Distance: 4509005.048322141
#   Cutoff: 0.35s, Best Distance: 3767179.4906124636
#   Cutoff: 0.4s, Best Distance: 3196302.8545902967
#   Cutoff: 0.45s, Best Distance: 3099945.331884995
#   Cutoff: 0.5s, Best Distance: 2534569.540979545
#   Cutoff: 0.55s, Best Distance: 2462056.8575219642
#   Cutoff: 0.6s, Best Distance: 2462056.8575219642
#   Cutoff: 0.65s, Best Distance: 2428093.0453002537
#   Cutoff: 0.7s, Best Distance: 2381345.965592291
#   Cutoff: 0.75s, Best Distance: 2318862.623306554
#   Cutoff: 0.8s, Best Distance: 2236696.9981367635
#   Cutoff: 0.85s, Best Distance: 2228786.8420701935
#   Cutoff: 0.9s, Best Distance: 2372061.665762634
#   Cutoff: 1s, Best Distance: 2462056.8575219642
# Plot saved for Toronto.
# Running LocalSearch for city: UKansasState
#   Cutoff: 0s, Best Distance: 136179.53760299034
#   Cutoff: 0.1s, Best Distance: 66309.50641739878
#   Cutoff: 0.15s, Best Distance: 66141.25933638433
#   Cutoff: 0.2s, Best Distance: 65518.22246636628
#   Cutoff: 0.25s, Best Distance: 63953.02430781314
#   Cutoff: 0.3s, Best Distance: 63136.59527733697
#   Cutoff: 0.35s, Best Distance: 62962.312807422444
#   Cutoff: 0.4s, Best Distance: 62962.312807422444
#   Cutoff: 0.45s, Best Distance: 62962.312807422444
#   Cutoff: 0.5s, Best Distance: 62962.312807422444
#   Cutoff: 0.55s, Best Distance: 62962.312807422444
#   Cutoff: 0.6s, Best Distance: 62962.312807422444
#   Cutoff: 0.65s, Best Distance: 62962.312807422444
#   Cutoff: 0.7s, Best Distance: 62962.312807422444
#   Cutoff: 0.75s, Best Distance: 62962.312807422444
#   Cutoff: 0.8s, Best Distance: 62962.312807422444
#   Cutoff: 0.85s, Best Distance: 62962.312807422444
#   Cutoff: 0.9s, Best Distance: 62962.312807422444
#   Cutoff: 1s, Best Distance: 62962.312807422444
# Plot saved for UKansasState.
# Running LocalSearch for city: UMissouri
#   Cutoff: 0s, Best Distance: 740388.9627323678
#   Cutoff: 0.1s, Best Distance: 642940.2444025783
#   Cutoff: 0.15s, Best Distance: 642940.2444025783
#   Cutoff: 0.2s, Best Distance: 641285.3728111722
#   Cutoff: 0.25s, Best Distance: 618466.65588191
#   Cutoff: 0.3s, Best Distance: 618466.65588191
#   Cutoff: 0.35s, Best Distance: 618466.65588191
#   Cutoff: 0.4s, Best Distance: 641285.3728111722
#   Cutoff: 0.45s, Best Distance: 618466.65588191
#   Cutoff: 0.5s, Best Distance: 618466.65588191
#   Cutoff: 0.55s, Best Distance: 618466.65588191
#   Cutoff: 0.6s, Best Distance: 618466.65588191
#   Cutoff: 0.65s, Best Distance: 599234.4703886537
#   Cutoff: 0.7s, Best Distance: 454260.811740957
#   Cutoff: 0.75s, Best Distance: 448374.66516941926
#   Cutoff: 0.8s, Best Distance: 421778.94214839285
#   Cutoff: 0.85s, Best Distance: 375985.8313172953
#   Cutoff: 0.9s, Best Distance: 309749.25705245446
#   Cutoff: 1s, Best Distance: 256607.10893941644
# Plot saved for UMissouri.
